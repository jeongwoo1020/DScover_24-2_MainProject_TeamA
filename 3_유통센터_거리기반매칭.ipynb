# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\yrlee\anaconda3\lib\site-packages (0.19.2)
# Requirement already satisfied: numpy in c:\users\yrlee\anaconda3\lib\site-packages (from folium) (1.21.5)
# Requirement already satisfied: requests in c:\users\yrlee\anaconda3\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: xyzservices in c:\users\yrlee\anaconda3\lib\site-packages (from folium) (2024.9.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\yrlee\anaconda3\lib\site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\yrlee\anaconda3\lib\site-packages (from folium) (3.1.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\yrlee\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\yrlee\anaconda3\lib\site-packages (from requests->folium) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\yrlee\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yrlee\anaconda3\lib\site-packages (from requests->folium) (2024.8.30)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yrlee\anaconda3\lib\site-packages (from requests->folium) (3.3)

# %%
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in c:\users\yrlee\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\yrlee\anaconda3\lib\site-packages (from geopy) (2.0)

# %%
import pandas as pd
import folium
from geopy.geocoders import Nominatim
from math import radians, cos, sin, sqrt, atan2
from IPython.display import display
from folium import Popup

# %%
# 1. 하버사인 공식을 이용한 거리 계산 함수
def haversine(lat1, lon1, lat2, lon2):
    R = 6371  # 지구의 반지름 (단위: km)
    dlat = radians(lat2 - lat1)
    dlon = radians(lon2 - lon1)
    a = sin(dlat / 2)**2 + cos(radians(lat1)) * cos(radians(lat2)) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    return R * c

# %%
# 2. 주소를 위경도로 변환하는 함수
def get_lat_lon(address):
    geolocator = Nominatim(user_agent="geoapi")
    location = geolocator.geocode(address)
    if location:
        return location.latitude, location.longitude
    else:
        raise ValueError("주소를 찾을 수 없습니다. 정확한 주소를 입력하세요.")

# %%
# 3. 사용자 위치 입력
while True:
    try:
        print("나의 위치를 입력해주세요 (예: 서울특별시 중구 세종대로 110):")
        my_address = input("주소: ")  # 사용자로부터 주소 입력받기
        my_lat, my_lon = get_lat_lon(my_address)  # 위경도 변환
        print(f"입력된 주소의 위경도: {my_lat}, {my_lon}")
        break  # 에러가 없으면 루프 종료
    except ValueError as e:
        print(f"에러: {e}. 다시 시도해주세요.")  # 에러 메시지 출력 후 재시도
# Out:
# 나의 위치를 입력해주세요 (예: 서울특별시 중구 세종대로 110):
# 주소: 서울특별시 중구 세종대로 110
# 입력된 주소의 위경도: 37.56635025, 126.97830900276097

# %%
# 4. 데이터 읽기 및 하버사인 거리 계산
file_path = '유통센터_공판장_도매시장_정리.csv'
data = pd.read_csv(file_path, encoding='euc-kr')

# 위경도 컬럼 이름 통일
data.rename(columns={'위도': '위도', '경도': '경도', '종류': '종류', '명칭': '명칭'}, inplace=True)

# 거리 계산
data['거리'] = data.apply(
    lambda row: haversine(my_lat, my_lon, row['위도'], row['경도']), axis=1
)

# %%
# 5. 새로운 필터링 로직
max_distances = {'유통센터': 50, '공판장': 35, '도매시장': 20}

def filter_or_nearest(group, type_name):
    filtered = group[group['거리'] <= max_distances[type_name]]
    if not filtered.empty:
        return filtered.nsmallest(3, '거리')
    # 범위 내 유통센터가 없을 경우 가장 가까운 한 곳 추천
    return group.nsmallest(1, '거리')

filtered_top_3_by_type = data.groupby('종류', group_keys=False).apply(lambda group: filter_or_nearest(group, group.name)).reset_index(drop=True)

filtered_top_3_by_type
# Out:
#      종류                   명칭                           주소         위도  \
# 0   공판장                동두천농협         강원특별자치도 동두천시 중앙로 207  37.899876
# 1  도매시장         서울강서농수산물도매시장              서울특별시 강서구 발산로40  37.553629
# 2  도매시장         서울가락농수산물도매시장           서울특별시 송파구 양재대로 932  37.493482
# 3  도매시장           구리농수산물도매시장        경기도 구리시 동구릉로 136번길 90  37.611932
# 4  유통센터  화성시 농산물 산지유통센터(APC)            화성시 팔탄면 푸른들판로 526  37.155560
# 5  유통센터             군자농협 APC  경기도 안산시 단원구 대부중앙로 141(대부동동)  37.241490
#
#            경도     시도구분 시도시군구       법정동코드           전화번호         거리
# 0  127.052241  강원특별자치도  동두천시  4125000000            NaN  37.651982
# 1  126.821398    서울특별시   강서구  1150000000  (02)2640-6000  13.903203
# 2  127.111504    서울특별시   송파구  1171000000  (02)3435-1000  14.268970
# 3  127.144917     경기도    구리시  4131000000  (031)560-5100  15.530393
# 4  126.900026      경기도   화성시  4159000000  031-5180-7810  46.198795
# 5  126.589279      경기도   안산시  4127000000   032-886-6100  49.856513

# %%
# 지도 생성
m = folium.Map(location=[my_lat, my_lon], zoom_start=12)

#나의 위치 표시
my_location_popup = folium.Popup(
    f"""
    <b>나의 위치</b><br>
    <b>주소:</b> {my_address}
    """, 
    max_width=300
)


# 나의 위치 표시
folium.Marker(
    location=[my_lat, my_lon],
    popup=my_location_popup,
    tooltip="나의 위치",
    icon=folium.Icon(color="red")
).add_to(m)

# %%
# 상위 3개씩 마커 추가
for _, row in filtered_top_3_by_type.iterrows():
    # 종류별 색상 설정
    if row['종류'] == "공판장":
        marker_color = "green"
    elif row['종류'] == "유통센터":
        marker_color = "blue"
    else:
        marker_color = "gray"

    #팝업 설정
    popup_content = f"""
    <b>이름:</b> {row['명칭']}<br>
    <b>종류:</b> {row['종류']}<br>
    <b>거리:</b> {row['거리']:.2f} km<br>
    <b>주소:</b> {row['주소']}
    """
    # 전화번호가 있을 경우 추가
    if not pd.isna(row.get('전화번호')) and row['전화번호']:
        popup_content += f"<br><b>전화번호:</b> {row['전화번호']}"
    
    popup = folium.Popup(popup_content, max_width=300)

    # 마커 추가
    folium.Marker(
        location=[row['위도'], row['경도']],
        popup=popup,
        tooltip=f"거리: {row['거리']:.2f} km",
        icon=folium.Icon(color=marker_color)
    ).add_to(m)

# %%
from IPython.display import display, HTML

# Folium 지도 객체 렌더링
display(m)

# 데이터 표 생성 및 렌더링
table_html = filtered_top_3_by_type.to_html(index=False, escape=False)

# 표를 Jupyter Notebook에서 바로 표시
display(HTML(f"""
    <h2>추천된 장소 목록</h2>
    {table_html}
"""))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b56d45ea003fe8dfbc5306dee5ecafa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b56d45ea003fe8dfbc5306dee5ecafa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b56d45ea003fe8dfbc5306dee5ecafa = L.map(
#                 &quot;map_6b56d45ea003fe8dfbc5306dee5ecafa&quot;,
#                 {
#                     center: [37.56635025, 126.97830900276097],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21cd853a23451e57bad84996a86e6b24 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_21cd853a23451e57bad84996a86e6b24.addTo(map_6b56d45ea003fe8dfbc5306dee5ecafa);
#
#
#             var marker_39e54051d573888dbf6014cd45bddf5a = L.marker(
#                 [37.56635025, 126.97830900276097],
#                 {
# }
#             ).addTo(map_6b56d45ea003fe8dfbc5306dee5ecafa);
#
#
#             var icon_a8711513ac4cff4a10e76040cbc36c26 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_39e54051d573888dbf6014cd45bddf5a.setIcon(icon_a8711513ac4cff4a10e76040cbc36c26);
#
#
#         var popup_bea3c80c8f96c9dd848b88ffd2a85b70 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_b1b58dc3b6ec1803597cb7fc49d27917 = $(`&lt;div id=&quot;html_b1b58dc3b6ec1803597cb7fc49d27917&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;나의 위치&lt;/b&gt;&lt;br&gt;     &lt;b&gt;주소:&lt;/b&gt; 서울특별시 중구 세종대로 110     &lt;/div&gt;`)[0];
#                 popup_bea3c80c8f96c9dd848b88ffd2a85b70.setContent(html_b1b58dc3b6ec1803597cb7fc49d27917);
#
#
#
#         marker_39e54051d573888dbf6014cd45bddf5a.bindPopup(popup_bea3c80c8f96c9dd848b88ffd2a85b70)
#         ;
#
#
#
#
#             marker_39e54051d573888dbf6014cd45bddf5a.bindTooltip(
#                 `&lt;div&gt;
#                      나의 위치
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_9cf8ceca89f4a9178e008c7be5a2a58e = L.marker(
#                 [37.8998762, 127.0522412],
#                 {
# }
#             ).addTo(map_6b56d45ea003fe8dfbc5306dee5ecafa);
#
#
#             var icon_3850fcb6cc66a369e60af0543cc4f42e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_9cf8ceca89f4a9178e008c7be5a2a58e.setIcon(icon_3850fcb6cc66a369e60af0543cc4f42e);
#
#
#         var popup_239cc8c0723001532ee3873c5c038e6b = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_05c3889389d604f2aae58a6a3b2a0ac1 = $(`&lt;div id=&quot;html_05c3889389d604f2aae58a6a3b2a0ac1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;이름:&lt;/b&gt; 동두천농협&lt;br&gt;     &lt;b&gt;종류:&lt;/b&gt; 공판장&lt;br&gt;     &lt;b&gt;거리:&lt;/b&gt; 37.65 km&lt;br&gt;     &lt;b&gt;주소:&lt;/b&gt; 강원특별자치도 동두천시 중앙로 207     &lt;/div&gt;`)[0];
#                 popup_239cc8c0723001532ee3873c5c038e6b.setContent(html_05c3889389d604f2aae58a6a3b2a0ac1);
#
#
#
#         marker_9cf8ceca89f4a9178e008c7be5a2a58e.bindPopup(popup_239cc8c0723001532ee3873c5c038e6b)
#         ;
#
#
#
#
#             marker_9cf8ceca89f4a9178e008c7be5a2a58e.bindTooltip(
#                 `&lt;div&gt;
#                      거리: 37.65 km
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_09e2495dfd0767426b0d799bcfa3bc45 = L.marker(
#                 [37.5536291, 126.8213981],
#                 {
# }
#             ).addTo(map_6b56d45ea003fe8dfbc5306dee5ecafa);
#
#
#             var icon_97941fa9cca70742a6ed8044c00e494b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;gray&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_09e2495dfd0767426b0d799bcfa3bc45.setIcon(icon_97941fa9cca70742a6ed8044c00e494b);
#
#
#         var popup_92f1511b1f74874740743defa596c0a4 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_1884a400cde622c20398850a7371c635 = $(`&lt;div id=&quot;html_1884a400cde622c20398850
#     <h2>추천된 장소 목록</h2>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>종류</th>
#       <th>명칭</th>
#       <th>주소</th>
#       <th>위도</th>
#       <th>경도</th>
#       <th>시도구분</th>
#       <th>시도시군구</th>
#       <th>법정동코드</th>
#       <th>전화번호</th>
#       <th>거리</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>공판장</td>
#       <td>동두천농협</td>
#       <td>강원특별자치도 동두천시 중앙로 207</td>
#       <td>37.899876</td>
#       <td>127.052241</td>
#       <td>강원특별자치도</td>
#       <td>동두천시</td>
#       <td>4125000000</td>
#       <td>NaN</td>
#       <td>37.651982</td>
#     </tr>
#     <tr>
#       <td>도매시장</td>
#       <td>서울강서농수산물도매시장</td>
#       <td>서울특별시 강서구 발산로40</td>
#       <td>37.553629</td>
#       <td>126.821398</td>
#       <td>서울특별시</td>
#       <td>강서구</td>
#       <td>1150000000</td>
#       <td>(02)2640-6000</td>
#       <td>13.903203</td>
#     </tr>
#     <tr>
#       <td>도매시장</td>
#       <td>서울가락농수산물도매시장</td>
#       <td>서울특별시 송파구 양재대로 932</td>
#       <td>37.493482</td>
#       <td>127.111504</td>
#       <td>서울특별시</td>
#       <td>송파구</td>
#       <td>1171000000</td>
#       <td>(02)3435-1000</td>
#       <td>14.268970</td>
#     </tr>
#     <tr>
#       <td>도매시장</td>
#       <td>구리농수산물도매시장</td>
#       <td>경기도 구리시 동구릉로 136번길 90</td>
#       <td>37.611932</td>
#       <td>127.144917</td>
#       <td>경기도</td>
#       <td>구리시</td>
#       <td>4131000000</td>
#       <td>(031)560-5100</td>
#       <td>15.530393</td>
#     </tr>
#     <tr>
#       <td>유통센터</td>
#       <td>화성시 농산물 산지유통센터(APC)</td>
#       <td>화성시 팔탄면 푸른들판로 526</td>
#       <td>37.155560</td>
#       <td>126.900026</td>
#       <td>경기도</td>
#       <td>화성시</td>
#       <td>4159000000</td>
#       <td>031-5180-7810</td>
#       <td>46.198795</td>
#     </tr>
#     <tr>
#       <td>유통센터</td>
#       <td>군자농협 APC</td>
#       <td>경기도 안산시 단원구 대부중앙로 141(대부동동)</td>
#       <td>37.241490</td>
#       <td>126.589279</td>
#       <td>경기도</td>
#       <td>안산시</td>
#       <td>4127000000</td>
#       <td>032-886-6100</td>
#       <td>49.856513</td>
#     </tr>
#   </tbody>
# </table>
